# %%
from sklearn import datasets
import pandas as pd

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df['Target'] = iris.get('target')
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Target
# 0         0
# ...

# %%
x = df.drop(columns = 'Target')
y = df['Target']

# %%
#before standardization
x.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
from sklearn.preprocessing import StandardScaler

# %%
x = StandardScaler().fit_transform(x)
pd.DataFrame(x)
# Out:
#             0         1         2         3
# 0   -0.900681  1.019004 -1.340227 -1.315444
# 1   -1.143017 -0.131979 -1.340227 -1.315444
# 2   -1.385353  0.328414 -1.397064 -1.315444
# 3   -1.506521  0.098217 -1.283389 -1.315444
# 4   -1.021849  1.249201 -1.340227 -1.315444
# ..        ...       ...       ...       ...
# 145  1.038005 -0.131979  0.819596  1.448832
# 146  0.553333 -1.282963  0.705921  0.922303
# 147  0.795669 -0.131979  0.819596  1.053935
# 148  0.432165  0.788808  0.933271  1.448832
# 149  0.068662 -0.131979  0.762758  0.790671
#
# [150 rows x 4 columns]

# %%
from sklearn.decomposition import PCA

# %%
#initializa PCA
pca = PCA(n_components= 3)
principal_components = pca.fit_transform(x)
principal_components
# Out:
# array([[-2.26470281,  0.4800266 , -0.12770602],
#        [-2.08096115, -0.67413356, -0.23460885],
#        [-2.36422905, -0.34190802,  0.04420148],
#        [-2.29938422, -0.59739451,  0.09129011],
#        [-2.38984217,  0.64683538,  0.0157382 ],
#        [-2.07563095,  1.48917752,  0.02696829],
#        [-2.44402884,  0.0476442 ,  0.3354704 ],
#        [-2.23284716,  0.22314807, -0.0886955 ],
#        [-2.33464048, -1.11532768,  0.14507686],
#        [-2.18432817, -0.46901356, -0.25376557],
#        [-2.1663101 ,  1.04369065, -0.2686811 ],
#        [-2.32613087,  0.13307834,  0.09375924],
#        [-2.2184509 , -0.72867617, -0.23091124],
#        [-2.6331007 , -0.96150673,  0.18079608],
#        [-2.1987406 ,  1.86005711, -0.472901  ],
#        [-2.26221453,  2.68628449,  0.03052661],
#        [-2.2075877 ,  1.48360936, -0.00534409],
#        [-2.19034951,  0.48883832, -0.04421532],
#        [-1.898572  ,  1.40501879, -0.37434327],
#        [-2.34336905,  1.12784938,  0.13263047],
# ...

# %%
#create this new dataset from PC's
df = pd.DataFrame(principal_components, columns = ['PC1','PC2','PC3'])
df['Target'] = iris.get('target')
df
# Out:
#           PC1       PC2       PC3  Target
# 0   -2.264703  0.480027 -0.127706       0
# 1   -2.080961 -0.674134 -0.234609       0
# 2   -2.364229 -0.341908  0.044201       0
# 3   -2.299384 -0.597395  0.091290       0
# 4   -2.389842  0.646835  0.015738       0
# ..        ...       ...       ...     ...
# 145  1.870503  0.386966  0.256274       2
# 146  1.564580 -0.896687 -0.026371       2
# 147  1.521170  0.269069  0.180178       2
# 148  1.372788  1.011254  0.933395       2
# 149  0.960656 -0.024332  0.528249       2
#
# [150 rows x 4 columns]

# %%
#Calculate the variance of each component

print("Variance of each PC's : ",pca.explained_variance_ratio_)
print("Total variation captured : ",sum(list(pca.explained_variance_ratio_))*100)
# Out:
# Variance of each PC's :  [0.72962445 0.22850762 0.03668922]
# Total variation captured :  99.48212908928451

# %%
#initializa PCA
pca = PCA(n_components= 2)
principal_components = pca.fit_transform(x)
#create this new dataset from PC's
df = pd.DataFrame(principal_components, columns = ['PC1','PC2'])
df['Target'] = iris.get('target')
df
# Out:
#           PC1       PC2  Target
# 0   -2.264703  0.480027       0
# 1   -2.080961 -0.674134       0
# 2   -2.364229 -0.341908       0
# 3   -2.299384 -0.597395       0
# 4   -2.389842  0.646835       0
# ..        ...       ...     ...
# 145  1.870503  0.386966       2
# 146  1.564580 -0.896687       2
# 147  1.521170  0.269069       2
# 148  1.372788  1.011254       2
# 149  0.960656 -0.024332       2
#
# [150 rows x 3 columns]

# %%
#Calculate the variance of each component

print("Variance of each PC's : ",pca.explained_variance_ratio_)
print("Total variation captured : ",sum(list(pca.explained_variance_ratio_))*100)
# Out:
# Variance of each PC's :  [0.72962445 0.22850762]
# Total variation captured :  95.81320720000164
